# %%
import duckdb

# %%
#install spatial extension
duckdb.sql("""
INSTALL spatial;
LOAD spatial;
""")

# %%
#read gml files
duckdb.sql("""
CREATE TABLE gml_data AS
SELECT *
FROM ST_Read('/home/cpadron/gitlab2/geospatial_big_data/data/OS/INSPIRE_AdministrativeUnit.gml');
""")

# %%
duckdb.sql("SELECT * FROM gml_data LIMIT 5").df()
# Out:
#                  gml_id                                         identifier  \
# 0  osgb7000000000176443  http://data.ordnancesurvey.co.uk/id/7000000000...
# 1  osgb7000000000002752  http://data.ordnancesurvey.co.uk/id/7000000000...
# 2  osgb7000000000006556  http://data.ordnancesurvey.co.uk/id/7000000000...
# 3  osgb7000000000003188  http://data.ordnancesurvey.co.uk/id/7000000000...
# 4  osgb7000000000007694  http://data.ordnancesurvey.co.uk/id/7000000000...
#
#   nationalCode           localId                            namespace  \
# 0    E06000060  7000000000176443  http://data.ordnancesurvey.co.uk/id
# 1    E04003786  7000000000002752  http://data.ordnancesurvey.co.uk/id
# 2    E04006387  7000000000006556  http://data.ordnancesurvey.co.uk/id
# 3    E04010268  7000000000003188  http://data.ordnancesurvey.co.uk/id
# 4    E04006824  7000000000007694  http://data.ordnancesurvey.co.uk/id
#
#              versionId LocalisedCharacterString language   sourceOfName  \
# 0  2025-04-09T12:17:04        Unitary Authority     None  Boundary-Line
# 1  2025-04-09T12:17:04             Civil Parish     None  Boundary-Line
# 2  2025-04-09T12:17:04             Civil Parish     None  Boundary-Line
# 3  2025-04-09T12:17:04             Civil Parish     None  Boundary-Line
# 4  2025-04-09T12:17:04             Civil Parish     None  Boundary-Line
#
#   pronunciation                text script residenceOfAuthority  \
# 0          None     Buckinghamshire   Latn                 None
# 1          None  St. John (Without)   Latn                 None
# 2          None         Ashmanhaugh   Latn                 None
# 3          None      Cofton Hackett   Latn                 None
# 4          None               Eydon   Latn                 None
#
#   beginLifespanVersion boundary  \
# 0  2025-04-09T12:17:04     None
# 1  2025-04-09T12:17:04     None
# 2  2025-04-09T12:17:04     None
# 3  2025-04-09T12:17:04     None
# 4  2025-04-09T12:17:04     None
#
#                                             geometry
# 0  [5, 4, 0, 0, 0, 0, 0, 0, 171, 68, 224, 72, 64,...
# 1  [5, 4, 0, 0, 0, 0, 0, 0, 111, 251, 2, 73, 38, ...
# 2  [5, 4, 0, 0, 0, 0, 0, 0, 129, 237, 25, 73, 175...
# 3  [5, 4, 0, 0, 0, 0, 0, 0, 89, 251, 194, 72, 115...
# 4  [5, 4, 0, 0, 0, 0, 0, 0, 233, 228, 220, 72, 83...
